# %%
#1. Create a list of 5 numbers and print the second element.

a=[10,20,30,40,50]
print(a[1])


#print fifth element

a=[10,20,30,40,50]
print(a[4])

#print -3 inedex value

a=[10,20,30,40,50]
print(a[-3])
# Out:
# 20
# 50
# 30

# %%
#2. Create a list with 3 different fruits and add one more fruit to the list.

fruites_list=["banana","strawberry","mango"]
fruites_list.append("apple")
fruites_list
# Out:
# ['banana', 'strawberry', 'mango', 'apple']

# %%
#3. Remove the first item from a list of 4 colors.

colors_list=["blue","white","green","orange"]
del colors_list[0]
print(colors_list)


#remove the third item from a list 

colors_list=["blue","white","green","orange"]
del colors_list[2]
print(colors_list)
# Out:
# ['white', 'green', 'orange']
# ['blue', 'white', 'orange']

# %%
#4. Find the length of a list that contains 7 items.
item_list=[1,3,5,7,9,2,3]
print(len(item_list))
# Out:
# 7

# %%
#5. Access and print the last element of a list containing 6 elements.
L=[1,2,3,4,5,6]
print(L[-1])
# Out:
# 6

# %%
#6. Create a list of 5 numbers and find the sum of all the numbers in the list.

num_list=[3,5,7,9,11]
total=sum(num_list)
print(total)
# Out:
# 35

# %%
#7. Create a list of 3 names and change the second name to a new name.

name_list=["anim","chanadra","barman"]

name_list[1]="shanto"
name_list


#7. Create a list of 3 names and change the second name to a new name.

L=["shoma","toma","tisha","arnob","supi"]

L[4]="shokti"
L
# Out:
# ['shoma', 'toma', 'tisha', 'arnob', 'shokti']

# %%
#8. Check if the number 10 is in a list of numbers from 1 to 5.

num_list=[4,6,10,9,12]

if 10 in num_list:
    print("10 is in the list")
else:
    print("10 is not in the list")
# Out:
# 10 is in the list
