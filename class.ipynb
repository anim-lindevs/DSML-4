# %% [markdown]
# #Identify the data types of the following values: 25, 3.14, "Python", True, [1, 2, 3, 4]. Print the type of each value using the `type()` function.

# %%
print(25)

type(25)
# Out:
# 25
# int

# %%
print(3.14)

type(3.14)
# Out:
# 3.14
# float

# %%
print("python")

type("python")
# Out:
# python
# str

# %%
print(True)

type(True)
# Out:
# True
# bool

# %%
print([1,2,3,4])

type([1,2,3,4])
# Out:
# [1, 2, 3, 4]
# list
